# %%
import pandas as pd
from bloom_filter import BloomFilter
from sklearn.ensemble import RandomForestClassifier
from utils import read_data, flatten_features, clean_data, create_new_columns
import numpy as np
# Out:
# /Users/ssmailova/Documents/UCU/MMDB/MMDB_2020_wiki_project/utils.py:14: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
file_name = 'experiment_big.json'
wiki_df = read_data(file_name)
print(wiki_df.columns)
wiki_df = flatten_features(wiki_df, 'length', ['old', 'new'])
wiki_df = flatten_features(wiki_df, 'revision', ['old', 'new'])

# create_new_columns(wiki_df)
wiki_df = clean_data(wiki_df)
print(wiki_df.columns)
important_columns = ['namespace', 'minor', 'edit_length', 'comment_length',
                     'length.old', 'length.new', 'revision.old', 'revision.new']

features = wiki_df[important_columns]
target = wiki_df.loc[:, ['bot']]
rf = RandomForestClassifier()
rf_model = rf.fit(features, target)

# get bots from our prediction
predicted_bool = rf_model.predict(features)
predicted_users = np.array(wiki_df.loc[predicted_bool, ['user']])

# train Bloom Filter
filter_size = 20000
hash_size = 8
bf = BloomFilter(filter_size, hash_size, debug=False)
bf.train_bloom_filter(predicted_users)

# %%
TP = 0
FN = 0
TN = 0
FP = 0

def evaluate(is_bot, is_bot_predicted):
    global TP
    global FN
    global TN
    global FP
    accuracy, precision, recall = 0,0,0
    if is_bot and is_bot_predicted:   
        TP += 1
    elif is_bot and not is_bot_predicted:
        FN += 1
    elif not is_bot and is_bot_predicted:
        FP += 1
    else:
        TN += 1
    all_observations = (TP + TN + FP + FN)
    if all_observations:
        accuracy = (TP + TN) / all_observations
    if TP:
        precision = TP / (TP + FP)
        recall = TP / (TP + FN)
    return accuracy, precision, recall

# %%
from sseclient import SSEClient as EventSource
import json
import time

url = 'https://stream.wikimedia.org/v2/stream/recentchange'
wiki = 'enwiki' #Client side filter
count = 0

for event in EventSource(url):
    if (int(str(hash(event.data))[-1]) < 2):
        try:
            change = json.loads(event.data)
            if change['wiki'] == wiki:
                user_name = change['user']
                is_bot = change['bot']
                print(f'User {user_name},\t is {"" if is_bot else " not"} a bot')
                is_bot_predicted = bf.is_in_bloom_filter(user_name)
                print(f'User {user_name},\t is {"" if is_bot_predicted else " not"} a bot \t\t(predicted)\n')
                count += 1
                accuracy, precision, recall = evaluate(is_bot, is_bot_predicted)
                if count % 10 == 0:
                    print(f"""
                    count = {count}
                    TP = {TP}, FP = {FP}, FN = {FN}, TN = {TN}
                    Accuracy = {accuracy * 100: .2f} %
                    Precision = {precision * 100: .2f} %
                    Recall = {recall * 100: .2f} %
                    """)


        except ValueError:
            continue
    else:
        continue
# Out:
# User Prad Nelluru,	 is  not a bot
# User Prad Nelluru,	 is  not a bot 		(predicted)
#
# User Somedifferentstuff,	 is  not a bot
# User Somedifferentstuff,	 is  not a bot 		(predicted)
#
# User Dontbeliedto,	 is  not a bot
# User Dontbeliedto,	 is  not a bot 		(predicted)
#
# User SteveMc25,	 is  not a bot
# User SteveMc25,	 is  not a bot 		(predicted)
#
# User Tassedethe,	 is  not a bot
# User Tassedethe,	 is  not a bot 		(predicted)
#
# User Fh1,	 is  not a bot
# User Fh1,	 is  not a bot 		(predicted)
#
# User SingingSinatra4,	 is  not a bot
# User SingingSinatra4,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User 2607:FEA8:BD20:F28:BDBE:6360:436D:132C,	 is  not a bot
# User 2607:FEA8:BD20:F28:BDBE:6360:436D:132C,	 is  not a bot 		(predicted)
#
#
#                     count = 10
#                     TP = 0, FP = 0, FN = 0, TN = 10
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User Motacilla,	 is  not a bot
# User Motacilla,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Soman,	 is  not a bot
# User Soman,	 is  not a bot 		(predicted)
#
# User SkepticalRaptor,	 is  not a bot
# User SkepticalRaptor,	 is  not a bot 		(predicted)
#
# User Footlessmouse,	 is  not a bot
# User Footlessmouse,	 is  not a bot 		(predicted)
#
# User Fishnagles,	 is  not a bot
# User Fishnagles,	 is  not a bot 		(predicted)
#
# User Dawnseeker2000,	 is  not a bot
# User Dawnseeker2000,	 is  not a bot 		(predicted)
#
# User 73.149.75.210,	 is  not a bot
# User 73.149.75.210,	 is  not a bot 		(predicted)
#
#
#                     count = 20
#                     TP = 0, FP = 0, FN = 0, TN = 20
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User Namcokid47,	 is  not a bot
# User Namcokid47,	 is  not a bot 		(predicted)
#
# User Namcokid47,	 is  not a bot
# User Namcokid47,	 is  not a bot 		(predicted)
#
# User Footlessmouse,	 is  not a bot
# User Footlessmouse,	 is  not a bot 		(predicted)
#
# User Stepho-wrs,	 is  not a bot
# User Stepho-wrs,	 is  not a bot 		(predicted)
#
# User EDITZ ACCURATE 11 18,	 is  not a bot
# User EDITZ ACCURATE 11 18,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User 79.79.123.156,	 is  not a bot
# User 79.79.123.156,	 is  not a bot 		(predicted)
#
# User 79.79.123.156,	 is  not a bot
# User 79.79.123.156,	 is  not a bot 		(predicted)
#
# User 79.79.123.156,	 is  not a bot
# User 79.79.123.156,	 is  not a bot 		(predicted)
#
# User 2601:151:8200:D000:C515:AE70:5A1E:8FC,	 is  not a bot
# User 2601:151:8200:D000:C515:AE70:5A1E:8FC,	 is  not a bot 		(predicted)
#
#
#                     count = 30
#                     TP = 0, FP = 0, FN = 0, TN = 30
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User Weathin,	 is  not a bot
# User Weathin,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User 108.46.169.57,	 is  not a bot
# User 108.46.169.57,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User 2A02:C7F:6072:2900:594F:2674:B87D:CA1D,	 is  not a bot
# User 2A02:C7F:6072:2900:594F:2674:B87D:CA1D,	 is  not a bot 		(predicted)
#
# User Tassedethe,	 is  not a bot
# User Tassedethe,	 is  not a bot 		(predicted)
#
# User SteveMc25,	 is  not a bot
# User SteveMc25,	 is  not a bot 		(predicted)
#
# User Footlessmouse,	 is  not a bot
# User Footlessmouse,	 is  not a bot 		(predicted)
#
# User Footlessmouse,	 is  not a bot
# User Footlessmouse,	 is  not a bot 		(predicted)
#
#
#                     count = 40
#                     TP = 0, FP = 0, FN = 0, TN = 40
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User 41.250.122.79,	 is  not a bot
# User 41.250.122.79,	 is  not a bot 		(predicted)
#
# User Arjayay,	 is  not a bot
# User Arjayay,	 is  not a bot 		(predicted)
#
# User Pegship,	 is  not a bot
# User Pegship,	 is  not a bot 		(predicted)
#
# User 108.46.142.165,	 is  not a bot
# User 108.46.142.165,	 is  not a bot 		(predicted)
#
# User Armadillopteryx,	 is  not a bot
# User Armadillopteryx,	 is  not a bot 		(predicted)
#
# User 41.250.122.79,	 is  not a bot
# User 41.250.122.79,	 is  not a bot 		(predicted)
#
# User 41.250.122.79,	 is  not a bot
# User 41.250.122.79,	 is  not a bot 		(predicted)
#
# User Rathfelder,	 is  not a bot
# User Rathfelder,	 is  not a bot 		(predicted)
#
# User Pppery,	 is  not a bot
# User Pppery,	 is  not a bot 		(predicted)
#
# User Reda Raouchaia,	 is  not a bot
# User Reda Raouchaia,	 is  not a bot 		(predicted)
#
#
#                     count = 50
#                     TP = 0, FP = 0, FN = 0, TN = 50
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User 2003:C9:1731:B700:3049:B9A1:D61D:85D6,	 is  not a bot
# User 2003:C9:1731:B700:3049:B9A1:D61D:85D6,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Eurohunter,	 is  not a bot
# User Eurohunter,	 is  not a bot 		(predicted)
#
# User Eurohunter,	 is  not a bot
# User Eurohunter,	 is  not a bot 		(predicted)
#
# User Namcokid47,	 is  not a bot
# User Namcokid47,	 is  not a bot 		(predicted)
#
# User ThurstonMitchell,	 is  not a bot
# User ThurstonMitchell,	 is  not a bot 		(predicted)
#
# User 2A02:C7F:6435:7E00:911:F7B4:6F2F:FC23,	 is  not a bot
# User 2A02:C7F:6435:7E00:911:F7B4:6F2F:FC23,	 is  not a bot 		(predicted)
#
# User Ser Amantio di Nicolao,	 is  not a bot
# User Ser Amantio di Nicolao,	 is  not a bot 		(predicted)
#
# User Badass Flare,	 is  not a bot
# User Badass Flare,	 is  not a bot 		(predicted)
#
# User 2A02:A318:C03A:E400:3545:EF0D:859B:DD7B,	 is  not a bot
# User 2A02:A318:C03A:E400:3545:EF0D:859B:DD7B,	 is  not a bot 		(predicted)
#
#
#                     count = 60
#                     TP = 0, FP = 0, FN = 0, TN = 60
#                     Accuracy =  100.00 %
#                     Precision =  0.00 %
#                     Recall =  0.00 %
#
# User Badass Flare,	 is  not a bot
# User Badass Flare,	 is  not a bot 		(predicted)
#
# User AnomieBOT,	 is  not a bot
# User AnomieBOT,	 is  a bot 		(predicted)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-d9ffbf329855> in <module>
#      40                     new_json = json.loads(event.data)
#      41                     new_json.update(new_fields)
# ---> 42                     save_json("false_predictions.json", str(new_json))
#      43
#      44
#
# NameError: name 'save_json' is not defined
